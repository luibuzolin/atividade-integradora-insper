# %% [markdown]
# # Modelo de Trabalho
# Comentar com um Markdown cada célula de código, explicando a linha de raciocínio de cada etapa.
#
# A cada alteração, salvar uma versão e deixar a anterior na pasta "backup" (Projeto Integrador 2024-09-14 16h 00 min)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Carregar o arquivo e analisar

# %%
df_completo = pd.read_csv("cs_bisnode_panel.csv")

# %%
df_completo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 287829 entries, 0 to 287828
# Data columns (total 48 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   comp_id               287829 non-null  float64
#  1   begin                 287829 non-null  object
#  2   end                   287829 non-null  object
#  3   COGS                  18257 non-null   float64
#  4   amort                 279789 non-null  float64
#  5   curr_assets           287698 non-null  float64
#  6   curr_liab             287698 non-null  float64
#  7   extra_exp             269300 non-null  float64
#  8   extra_inc             269300 non-null  float64
#  9   extra_profit_loss     270626 non-null  float64
#  10  finished_prod         17485 non-null   float64
#  11  fixed_assets          287698 non-null  float64
#  12  inc_bef_tax           280392 non-null  float64
#  13  intang_assets         287689 non-null  float64
# ...

# %% [markdown]
# ## Remova as colunas
# 'COGS', 'finished_prod', 'net_dom_sales',
# 'net_exp_sales', 'wages', 'D] pois elas apresentam um percentua
# considerável de missing data

# %%
df_completo = df_completo.drop(['COGS', 'finished_prod', 'net_dom_sales', 'net_exp_sales', 'wages', 'D'], axis = 1)

# %%
import missingno as msno

# %%
pd.isna(df_completo).sum().sum()
# Out:
# 1252390

# %%
msno.bar(df_completo)
# Out:
# <Axes: >
